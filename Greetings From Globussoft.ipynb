# %% [markdown]
# # Question: - 1

# %% [markdown]
# i can't understand,How to get 9 as a output.

# %%
# 5,1,3,1,7,2
#first =5, second =(1,1&3), second =1, first =(3,3&1),first =3,second =(1,1&7), second=1,first=7&2 T[first=17,second=2]
                                                             #second=1&7,first=2 T[first=10,second=9]
                           #second=1&3,first=(1,1&7,1&7&2),first=1,second=7&2 T[first=6,second=13]
                                                          #first=1&7&2 T[first=15,second=4]
                                                    #first=1&7&2 T[first=15,second=4]

# %% [markdown]
# # i need more examples for better understand

# %% [markdown]
# # Question: - 2

# %% [markdown]
# One rich person decided to make himself a great garden. The garden should have a from of
# equilateral triangle. There should be a gazebo inside the garden. The gazebo will be connected
# with the triangle vertexes by roads. The lengths of all three roads are known. Those numbers are
# sacred for this rich man. The expense of building such a garden will depend on the area of the
# garden. Help the rich man by calculating what will be the area of his garden.

# %% [markdown]
# The first line of the input contains number t – the amount of tests. Then t test descriptions follow.
# Each test consist of three integers a, b, c - the lengths of the roads. It is guaranteed that it's
# possible to build such a garden.

# %% [markdown]
# # SOLUTION:-

# %% [markdown]
# ![Screenshot%202022-12-17%20200332.png](attachment:Screenshot%202022-12-17%20200332.png)

# %% [markdown]
# Let's consider the picture above would be a rich man's garden. Where "D" is gazebo and "AD", "BD", "CD" are three roads.
# Let, length of AD= d, length of BD= e and length of CD = f

# %% [markdown]
# Now we have a formula for calculating the area of an equilateral triangle *(I can prove this formula)

# %% [markdown]
# ![Screenshot%20%2898%29.png](attachment:Screenshot%20%2898%29.png)

# %% [markdown]
# Where S= The Area Of The Triangle and s= (d+e+f)/2

# %%
#variable assigned for Count the number of test
test_number=1
#variable assigned for input the length of AD
d=int(input("PLEASE INPUT THE LENGTH OF AD ="))
#variable assigned for input the length of BD
e=int(input("PLEASE INPUT THE LENGTH OF BD ="))
#variable assigned for input the length of CD
f=int(input("PLEASE INPUT THE LENGTH OF CD ="))
# Out:
# PLEASE INPUT THE LENGTH OF AD =3
# PLEASE INPUT THE LENGTH OF BD =4
# PLEASE INPUT THE LENGTH OF CD =5

# %%
#import math for sqrt function
import math

# %%
#DIVIDING THE MAIN FORMULA INTO SMALL SMALL PART
p=d**2*(math.sqrt(3)/4)
q=e**2*(math.sqrt(3)/4)
r=f**2*(math.sqrt(3)/4)
s=(d+e+f)/2
x=3*math.sqrt(s*(s-d)*(s-e)*(s-f))
ans=(p+q+r+x)/2

# %%
#Final Output
print("Test Number=", test_number)
print("The Area of the Traingle=",round(ans,2))
#for the next experiment
test_number+=1
# Out:
# Test Number= 1
# The Area of the Traingle= 19.83

# %% [markdown]
# # Question: - 3

# %% [markdown]
# # Question: - 4

# %%
# A Python program to print all 
# permutations using library function 
from itertools import permutations 
  
  
# Get all permutations of[2,3,4,5] 
perm = permutations([2,3,4,5]) 

#define a empty list
list_p=[]
# Print the obtained permutations 
for i in list(perm):
    list_p.append(list(i))

# %%
list_p
# Out:
# [[2, 3, 4, 5],
#  [2, 3, 5, 4],
#  [2, 4, 3, 5],
#  [2, 4, 5, 3],
#  [2, 5, 3, 4],
#  [2, 5, 4, 3],
#  [3, 2, 4, 5],
#  [3, 2, 5, 4],
#  [3, 4, 2, 5],
#  [3, 4, 5, 2],
#  [3, 5, 2, 4],
#  [3, 5, 4, 2],
#  [4, 2, 3, 5],
#  [4, 2, 5, 3],
#  [4, 3, 2, 5],
#  [4, 3, 5, 2],
#  [4, 5, 2, 3],
#  [4, 5, 3, 2],
#  [5, 2, 3, 4],
#  [5, 2, 4, 3],
#  [5, 3, 2, 4],
#  [5, 3, 4, 2],
#  [5, 4, 2, 3],
#  [5, 4, 3, 2]]

# %% [markdown]
# # Question: - 5

# %% [markdown]
# First let me say that I have never solved this type of puzzle before. So, it's a little difficult for me. I may be able to solve this problem but given time is not enough for me, if you give some extra time I can try to solve this problem.
